# %%
# !wget https://cernbox.cern.ch/index.php/s/AtBT8y4MiQYFcgc/download -O singlePhoton.hdf5
# !wget https://cernbox.cern.ch/index.php/s/FbXw3V4XNyYB3oA/download -O SingleElectron.hdf5
# !pip install h5py
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# Collecting h5py
#   Downloading h5py-3.6.0-cp39-cp39-win_amd64.whl (2.8 MB)
# Requirement already satisfied: numpy>=1.14.5 in d:\python\lib\site-packages (from h5py) (1.22.3)
# Installing collected packages: h5py
# Successfully installed h5py-3.6.0
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\python\python.exe -m pip install --upgrade pip' command.

# %%
# memory size of numpy array
import os, psutil

def getAmountOfUsedMemoryGb():
    process = psutil.Process(os.getpid())
    return round(process.memory_info().rss / 1024 / 1024 / 1024,3)  # in GB

# %%
# !rm -rf download*
import os
import h5py

print(os.listdir())
photon = h5py.File('singlePhoton.hdf5', 'r')
electron = h5py.File("SingleElectron.hdf5", 'r')

print("Single Photon File")
print(photon.keys())
print(photon['X'], photon['y'])
print("\n")
print("Single Electron File")
print(electron.keys())
print(electron['X'], electron['y'])
# Out:
# ['.git', '.ipynb_checkpoints', 'GSoC E2E Test.pdf', 'README.md', 'singleElectron.hdf5', 'singlePhoton.hdf5', 'Untitled.ipynb']
# Single Photon File
# <KeysViewHDF5 ['X', 'y']>
# <HDF5 dataset "X": shape (249000, 32, 32, 2), type "<f4"> <HDF5 dataset "y": shape (249000,), type "<f4">
#
#
# Single Electron File
# <KeysViewHDF5 ['X', 'y']>
# <HDF5 dataset "X": shape (249000, 32, 32, 2), type "<f4"> <HDF5 dataset "y": shape (249000,), type "<f4">
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from collections import Counter

import numpy as np
py, ey = np.array(photon['y']), np.array(electron['y'])
pX, eX = np.array(photon['X']), np.array(electron["X"])

print(Counter(py), Counter(ey))
# Out:
# Counter({0.0: 249000}) Counter({1.0: 249000})

# %%
val_to_label = ["photon", 'electron']
getAmountOfUsedMemoryGb()
# Out:
# 4.503

# %%
X = np.concatenate([pX, eX], axis=0)
y = np.concatenate([py, ey], axis=0)

# free memory
py, ey = None, None 
pX, eX = None, None

# %%
print(getAmountOfUsedMemoryGb(), "Gb")
# Out:
# 4.505 Gb

# %%
def shuffle(X, y):
  idxs = np.arange(X.shape[0])
  idxs = np.random.permutation(idxs)
  return X[idxs], y[idxs]


X, y = shuffle(X, y)
print(getAmountOfUsedMemoryGb(), "Gb")
# Out:
# 4.505 Gb

# %%
import matplotlib.pyplot as plt 

def getNRandom(N, Range):
    return np.random.permutation(np.arange(Range))[:N]

v = 9
plt.figure(figsize=(12, 48))

for i,j in enumerate(getNRandom(9, X.shape[0])):
  cls = y[j]
  hit_energy, hit_time = X[j, :, :, 0], X[j, :, :, 1]
  dat = np.concatenate([hit_energy, hit_time], axis = 0)
  plt.subplot(v, 2, 2 * i  + 1)
  plt.imshow(hit_energy, cmap='magma')
  plt.title(f"hit_energy for {val_to_label[int(cls)] }")

  plt.subplot(v, 2, 2 * i  + 2)
  plt.imshow(hit_time,  cmap='magma')
  plt.title(f"hit_time for {val_to_label[int(cls)] }")

# %%
from tensorflow import keras 
from tensorflow.keras import layers

model = keras.Sequential()
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(32,32,2)))
model.add(layers.AveragePooling2D())
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(layers.AveragePooling2D())
model.add(layers.Flatten())
model.add(layers.Dense(units=120, activation='relu'))
model.add(layers.Dense(units=84, activation='relu'))
model.add(layers.Dense(units=1, activation = 'sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=5, batch_size=32)
model.evaluate(X, y)
# Out:
# Epoch 1/5
# 15563/15563 [==============================] - 379s 24ms/step - loss: 0.6057 - accuracy: 0.6759
# Epoch 2/5
# 10145/15563 [==================>...........] - ETA: 2:16 - loss: 0.5752 - accuracy: 0.7065
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a20f75072759> in <module>
#      13
#      14 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# ---> 15 model.fit(X, y, epochs=5, batch_size=32)
#      16 model.evaluate(X, y)
#
# D:\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# D:\Anaconda\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# D:\Anaconda\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# D:\Anaconda\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# D:\Anaconda\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# D:\Anaconda\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
model = keras.applications.ResNet50V2(include_top=False)
print(model)

#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.fit(X, y, epochs=5, batch_size=32)
#model.evaluate(X, y)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)
